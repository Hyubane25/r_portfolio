# %% [markdown]
# <a href="https://www.kaggle.com/code/janreyubane/lesson-2-create-your-own-data-frame?scriptVersionId=278183997" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ## Title: Lesson 2 create your own data frame
# #Author: Janrey Ubane
# #Date: `r Sys.Date()`
# #Output: html_document
#
#
# ## Step 1: Load packages (Skipped)
# ```{r}
# packageVersion("tidyverse")
# library(tidyverse)
# library(dplyr)
# ```
#
# ## Step 2: Create data frame
# ```{r}
# #raw data
# names <- c("John", "Shemken", "Pig pig", "Nik nik")
# age <- c(3,4,5,6)
#
# #dataframe
# people <- data.frame(names,age)
# ```
#
# ## Step 3: inspect the data frame
# ```{r}
# head(people)
# str(people)
# glimpse(people)
# colnames(people)
# mutate(people, age_in_20 = age + 20)
# ```
#
# ## Step 4: Try it yourself
# ```{r}
#
# ```

# %%
fruits <- c("banana", "apple", "avocado", "orange", "mango")
fruit_rank <- c("3", "4", "2", "5", "1")
fruit_ranks <- data.frame(fruits, fruit_rank);
head(fruit_ranks)
glimpse(fruit_ranks)
#mutate(fruit_ranks, percentage = mean(fruit_rank))
# Out:
#   fruits  fruit_rank
# 1 banana  3
# 2 apple   4
# 3 avocado 2
# 4 orange  5
# 5 mango   1
# Error in glimpse(fruit_ranks): could not find function "glimpse"
# Traceback:
